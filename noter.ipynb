# %%
import csv
import json

# %%
with open('data/A3_Tool.json', mode='r') as file:
    data = json.load(file)


print(data['Area of spaces'])
print(len(data['Area of spaces']))
# Out:
# {'Office': 2182.77, 'Toilet lobby': 158.6, 'Atrium w/ café': 343.37, 'Auditorium': 245.38, 'Multipurpose space': 251.74, 'Materials library and student work area': 324.06, 'Student work area': 256.64, 'Elevator': 41.83, 'Meeting room': 267.27, 'Toilet': 110.48, 'Lounge': 92.16, 'Room': 240.57, 'Terrace': 365.53, 'Reception': 30.0, 'Corridor': 2070.8, 'Stairs': 252.85, 'Storage/utility': 991.73, 'Shower': 20.44, 'Utility': 142.43}
# 19

# %%
total_area = sum(data['Area of spaces'].values())
print(f'Total area of spaces: {total_area} m²')
# Out:
# Total area of spaces: 8388.65 m²

# %%
print(data["Total summed area"])
# Out:
# 9290.59
